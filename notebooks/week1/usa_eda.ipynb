# %%
import pandas as pd
url ="https://raw.githubusercontent.com/Vincent2308/Corporate-Bankruptcy/main/data/raw/U.S/american_bankruptcy_dataset.csv"
df = pd.read_csv(url)

rename_map = {
    'X1': 'current_assets',
    'X2': 'cost_of_goods_sold',
    'X3': 'depreciation_amortization',
    'X4': 'ebitda',
    'X5': 'inventory',
    'X6': 'net_income',
    'X7': 'total_receivables',
    'X8': 'market_value',
    'X9': 'net_sales',
    'X10': 'total_assets',
    'X11': 'long_term_debt',
    'X12': 'ebit',
    'X13': 'gross_profit',
    'X14': 'current_liabilities',
    'X15': 'retained_earnings',
    'X16': 'total_revenue',
    'X17': 'total_liabilities',
    'X18': 'operating_expenses'
}

df = df.rename(columns=rename_map)

df.to_csv('american_bankruptcy_dataset_renamed.csv', index=False)

df.head()
# Out:
#   company_name   fyear status_label  current_assets  cost_of_goods_sold  \
# 0          C_1  1999.0        alive        511267.0          740998.000
# 1          C_1  2000.0        alive        485856.0             701.854
# 2          C_1  2001.0        alive        436656.0          710199.000
# 3          C_1  2002.0        alive        396412.0             686.621
# 4          C_1  2003.0        alive        432204.0             709.292
#
#    depreciation_amortization    ebitda  inventory  net_income  \
# 0                   833107.0  180447.0   18373.00    70658.00
# 1                   713811.0  179987.0   18577.00       45.79
# 2                   526477.0  217699.0   22496.00     4711.00
# 3                   496747.0  164658.0   27172.00     3573.00
# 4                   523302.0  248666.0      26.68    20811.00
#
#    total_receivables  ...  long_term_debt        ebit  gross_profit  \
# 0          89031.000  ...          35.163  201026.000       128.348
# 1          64367.000  ...       18531.000  204065.000    115187.000
# 2          27207.000  ...         -58.939     139.603     77528.000
# 3          30745.000  ...         -12.410  124106.000     66322.000
# 4             47.491  ...        3504.000  131884.000    104661.000
#
#    current_liabilities  retained_earnings  total_revenue  total_liabilities  \
# 0          1024333.000           372.7519       401483.0        1024333.000
# 1           874255.000           377.1180       361642.0         874255.000
# 2           638721.000           364.5928       399964.0         638721.000
# 3           606337.000           143.3295       391633.0         606337.000
# 4              651.958           308.9071       407608.0            651.958
#
#    operating_expenses  Division  MajorGroup
# 0            935302.0         D          37
# 1            809888.0         D          37
# 2            611514.0         D          37
# 3            575592.0         D          37
# 4            604467.0         D          37
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78682 entries, 0 to 78681
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   company_name               78682 non-null  object
#  1   fyear                      78682 non-null  float64
#  2   status_label               78682 non-null  object
#  3   current_assets             78682 non-null  float64
#  4   cost_of_goods_sold         78682 non-null  float64
#  5   depreciation_amortization  78682 non-null  float64
#  6   ebitda                     78682 non-null  float64
#  7   inventory                  78682 non-null  float64
#  8   net_income                 78682 non-null  float64
#  9   total_receivables          78682 non-null  float64
#  10  market_value               78682 non-null  float64
#  11  net_sales                  78682 non-null  float64
#  12  total_assets               78682 non-null  float64
#  13  long_term_debt             78682 non-null  float64
#  14  ebit                       78682 non-null  float64
#  15  gross_profit               78682 non-null  float64
#  16  current_liabilities        78682 non-null  float64
#  17  retained_earnings          78682 non-null  float64
#  18  total_revenue              78682 non-null  float64
#  19  total_liabilities          78682 non-null  float64
#  20  operating_expenses         78682 non-null  float64
#  21  Division                   78682 non-null  object
#  22  MajorGroup                 78682 non-null  int64
# dtypes: float64(19), int64(1), object(3)
# memory usage: 13.8+ MB

# %%
df.describe()
# Out:
#               fyear  current_assets  cost_of_goods_sold  \
# count  78682.000000    7.868200e+04        7.868200e+04
# mean    2007.506317    2.133141e+05        5.994709e+05
# std        5.742768    7.016291e+05        2.065452e+06
# min     1999.000000   -2.498000e+03        7.000000e-03
# 25%     2002.000000    1.272000e+03        3.282525e+03
# 50%     2007.000000    2.201650e+04        4.326650e+04
# 75%     2012.000000    1.539940e+05        3.293620e+05
# max     2018.000000    3.132258e+07        6.723494e+07
#
#        depreciation_amortization        ebitda     inventory    net_income  \
# count               7.868200e+04  7.868200e+04  7.868200e+04  7.868200e+04
# mean                3.797745e+05  1.508433e+05  2.471565e+04  4.426177e+04
# std                 2.021659e+06  7.115052e+05  9.778169e+04  2.240017e+05
# min                -3.666450e+05 -2.300000e+01  0.000000e+00 -5.043795e+06
# 25%                 1.439100e+03  0.000000e+00  7.440000e+01 -7.677500e+02
# 50%                 2.104450e+04  5.000000e+02  1.216000e+03  3.030000e+02
# 75%                 1.808215e+05  1.601050e+04  1.234475e+04  1.909775e+04
# max                 1.632456e+08  2.068708e+07  4.440438e+06  9.783515e+06
#
#        total_receivables  market_value     net_sales  total_assets  \
# count       7.868200e+04  7.868200e+04  7.868200e+04  7.868200e+04
# mean        6.942115e+04  1.723757e+05  5.102166e+04  1.233971e+05
# std         2.847994e+05  6.007523e+05  2.204076e+05  4.877100e+05
# min        -4.512135e+06 -4.367571e+06  0.000000e+00  7.000000e-03
# 25%        -9.000000e+00  3.554325e+02  0.000000e+00  9.580750e+02
# 50%         1.121900e+03  1.145950e+04  6.750000e+02  1.086600e+04
# 75%         3.325675e+04  1.099000e+05  1.677175e+04  6.928050e+04
# max         1.256672e+07  2.786440e+07  1.191851e+07  2.786969e+07
#
#        long_term_debt          ebit  gross_profit  current_liabilities  \
# count    7.868200e+04  7.868200e+04  7.868200e+04         7.868200e+04
# mean     1.397351e+04  4.788783e+04  6.791101e+04         5.488639e+05
# std      1.978544e+05  8.134077e+05  2.582180e+05         2.369004e+06
# min     -1.605370e+07 -2.148494e+07 -6.000000e+00        -1.964999e+06
# 25%     -2.636000e+03 -3.078750e+04  2.064025e+02         1.930780e+03
# 50%      3.137400e+01 -5.985500e+00  4.106500e+03         3.281900e+04
# 75%      8.379750e+03  2.215800e+04  3.840950e+04         2.997678e+05
# max      7.521731e+06  3.095666e+07  1.154206e+07         1.679396e+08
#
#        retained_earnings  total_revenue  total_liabilities  \
# count       7.868200e+04   7.868200e+04       7.868200e+04
# mean        4.482444e+05   3.517166e+05       5.488639e+05
# std         5.110524e+06   1.359127e+06       2.369004e+06
# min         1.000000e-04   7.000000e-03      -1.964999e+06
# 25%         4.644980e+01   1.957025e+03       1.930780e+03
# 50%         3.727403e+02   1.798550e+04       3.281900e+04
# 75%         3.097385e+03   1.497210e+05       2.997678e+05
# max         4.670929e+08   4.042171e+07       1.679396e+08
#
#        operating_expenses    MajorGroup
# count        7.868200e+04  78682.000000
# mean         4.761371e+05     45.181477
# std          2.079919e+06     19.812783
# min         -3.171970e+05      1.000000
# 25%          3.043000e+03     30.000000
# 50%          3.701000e+04     38.000000
# 75%          2.625520e+05     59.000000
# max          1.657008e+08     99.000000

# %%
df.isna().sum()
# Out:
# company_name                 0
# fyear                        0
# status_label                 0
# current_assets               0
# cost_of_goods_sold           0
# depreciation_amortization    0
# ebitda                       0
# inventory                    0
# net_income                   0
# total_receivables            0
# market_value                 0
# net_sales                    0
# total_assets                 0
# long_term_debt               0
# ebit                         0
# gross_profit                 0
# current_liabilities          0
# retained_earnings            0
# total_revenue                0
# total_liabilities            0
# operating_expenses           0
# Division                     0
# MajorGroup                   0
# dtype: int64

# %%
df['status_label'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='status_label'>

# %%
df.dtypes
# Out:
# company_name                  object
# fyear                        float64
# status_label                  object
# current_assets               float64
# cost_of_goods_sold           float64
# depreciation_amortization    float64
# ebitda                       float64
# inventory                    float64
# net_income                   float64
# total_receivables            float64
# market_value                 float64
# net_sales                    float64
# total_assets                 float64
# long_term_debt               float64
# ebit                         float64
# gross_profit                 float64
# current_liabilities          float64
# retained_earnings            float64
# total_revenue                float64
# total_liabilities            float64
# operating_expenses           float64
# Division                      object
# MajorGroup                     int64
# dtype: object

# %%
df['bankrupt'] = df['status_label'].map({'alive': 0, 'failed': 1})

# %%
numeric_df = df.select_dtypes(include=['number']).copy()

# %%
year_cols = numeric_df.columns.drop('bankrupt')

numeric_df[year_cols] = numeric_df.groupby(df['fyear'])[year_cols].transform(
    lambda x: (x - x.mean()) / x.std()
)

# %%
corr_with_target = numeric_df.corr()['bankrupt'].sort_values(ascending=False)
print(corr_with_target)
# Out:
# bankrupt                     1.000000
# ebitda                       0.040319
# total_revenue                0.023872
# inventory                    0.023358
# cost_of_goods_sold           0.010284
# total_assets                -0.003651
# operating_expenses          -0.007232
# depreciation_amortization   -0.007735
# total_liabilities           -0.010748
# current_liabilities         -0.010748
# total_receivables           -0.011109
# market_value                -0.012773
# retained_earnings           -0.017193
# net_sales                   -0.017286
# gross_profit                -0.017453
# current_assets              -0.023660
# net_income                  -0.027529
# ebit                        -0.039998
# long_term_debt              -0.045304
# MajorGroup                  -0.062428
# fyear                             NaN
# Name: bankrupt, dtype: float64

# %%
"""
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15,12))
sns.heatmap(numeric_df.corr(), cmap='coolwarm', center=0)
plt.title("Correlation Matrix (Numeric Only, Normalized per Year)")
plt.show()
"""
# Out:
# '\nimport seaborn as sns\nimport matplotlib.pyplot as plt\n\nplt.figure(figsize=(15,12))\nsns.heatmap(numeric_df.corr(), cmap=\'coolwarm\', center=0)\nplt.title("Correlation Matrix (Numeric Only, Normalized per Year)")\nplt.show()\n'

# %%
df = df.drop(columns=['status_label'])

# %%
df['bankrupt'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='bankrupt'>

# %%
# Compute important financial ratios
df['leverage'] = df['total_liabilities'] / df['total_assets']
df['current_ratio'] = df['current_assets'] / df['current_liabilities']
df['quick_ratio'] = (df['current_assets'] - df['inventory']) / df['current_liabilities']
df['roa'] = df['net_income'] / df['total_assets']
df['ebit_margin'] = df['ebit'] / df['net_sales']
df['gross_margin'] = df['gross_profit'] / df['net_sales']
df['retained_to_assets'] = df['retained_earnings'] / df['total_assets']

# %%
df.to_csv('american_bankruptcy_dataset_renamed_ratios.csv', index=False)

# %%
df.head()
# Out:
#   company_name   fyear  current_assets  cost_of_goods_sold  \
# 0          C_1  1999.0        511267.0          740998.000
# 1          C_1  2000.0        485856.0             701.854
# 2          C_1  2001.0        436656.0          710199.000
# 3          C_1  2002.0        396412.0             686.621
# 4          C_1  2003.0        432204.0             709.292
#
#    depreciation_amortization    ebitda  inventory  net_income  \
# 0                   833107.0  180447.0   18373.00    70658.00
# 1                   713811.0  179987.0   18577.00       45.79
# 2                   526477.0  217699.0   22496.00     4711.00
# 3                   496747.0  164658.0   27172.00     3573.00
# 4                   523302.0  248666.0      26.68    20811.00
#
#    total_receivables  market_value  ...  Division  MajorGroup  bankrupt  \
# 0          89031.000     191226.00  ...         D          37         0
# 1          64367.000     160444.00  ...         D          37         0
# 2          27207.000     112244.00  ...         D          37         0
# 3          30745.000        109.59  ...         D          37         0
# 4             47.491     128656.00  ...         D          37         0
#
#    leverage  current_ratio  quick_ratio       roa  ebit_margin  gross_margin  \
# 0  6.252948       0.499122     0.481185  0.431325   598.259617      0.381968
# 1  6.972175       0.555737     0.534488  0.000365   636.529524    359.296921
# 2  4.245009       0.683641     0.648421  0.031310     0.000487      0.270521
# 3  2.978445       0.653782     0.608968  0.017551     0.477415      0.255130
# 4  0.004967     662.932275   662.891352  0.158547     0.533414      0.423309
#
#    retained_to_assets
# 0            0.002275
# 1            0.003008
# 2            0.002423
# 3            0.000704
# 4            0.002353
#
# [5 rows x 30 columns]

# %%
df[['leverage','current_ratio','roa','ebit_margin']].hist(bins=50, figsize=(12,8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df[['leverage','current_ratio','roa','ebit_margin']].hist(bins=50, figsize=(12,8))
#       2 plt.show()
#
# File ~/.pyenv/versions/3.13.1/lib/python3.13/site-packages/pandas/plotting/_core.py:251, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     164 """
#     165 Make a histogram of the DataFrame's columns.
#     166
#    (...)    248     >>> hist = df.hist(bins=3)
#     249 """
#     250 plot_backend = _get_plot_backend(backend)
# --> 251 return plot_backend.hist_frame(
#     252     data,
#     253     column=column,
#     254     by=by,
#     255     grid=grid,
#     256     xlabelsize=xlabelsize,
#     257     xrot=xrot,
#     258     ylabelsize=ylabelsize,
#     259     yrot=yrot,
#     260     ax=ax,
#     261     sharex=sharex,
#     262     sharey=sharey,
#     263     figsize=figsize,
#     264     layout=layout,
#     265     legend=legend,
#     266     bins=bins,
#     267     **kwargs,
#     268 )
#
# File ~/.pyenv/versions/3.13.1/lib/python3.13/site-packages/pandas/plotting/_matplotlib/hist.py:570, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     568 if legend and can_set_label:
#     569     kwds["label"] = col
# --> 570 ax.hist(data[col].dropna().values, bins=bins, **kwds)
#     571 ax.set_title(col)
#     572 ax.grid(grid)
#
# File ~/.pyenv/versions/3.13.1/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.13.1/lib/python3.13/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/.pyenv/versions/3.13.1/lib/python3.13/site-packages/matplotlib/axes/_axes.py:7132, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7128 # Loop through datasets
#    7129 for i in range(nx):
#    7130     # this will automatically overwrite bins,
#    7131     # so that each histogram uses the same bins
# -> 7132     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7133     tops.append(m)
#    7134 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File ~/.pyenv/versions/3.13.1/lib/python3.13/site-packages/numpy/lib/_histograms_impl.py:792, in histogram(a, bins, range, density, weights)
#     687 r"""
#     688 Compute the histogram of a dataset.
#     689
#    (...)    788
#     789 """
#     790 a, weights = _ravel_and_check_weights(a, weights)
# --> 792 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     794 # Histogram is an integer or a float array depending on the weights.
#     795 if weights is None:
#
# File ~/.pyenv/versions/3.13.1/lib/python3.13/site-packages/numpy/lib/_histograms_impl.py:425, in _get_bin_edges(a, bins, range, weights)
#     422     if n_equal_bins < 1:
#     423         raise ValueError('`bins` must be positive, when an integer')
# --> 425     first_edge, last_edge = _get_outer_edges(a, range)
#     427 elif np.ndim(bins) == 1:
#     428     bin_edges = np.asarray(bins)
#
# File ~/.pyenv/versions/3.13.1/lib/python3.13/site-packages/numpy/lib/_histograms_impl.py:309, in _get_outer_edges(a, range)
#     306         raise ValueError(
#     307             'max must be larger than min in range parameter.')
#     308     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 309         raise ValueError(
#     310             f"supplied range of [{first_edge}, {last_edge}] is not finite")
#     311 elif a.size == 0:
#     312     # handle empty arrays. Can't determine range, so use 0-1.
#     313     first_edge, last_edge = 0, 1
#
# ValueError: supplied range of [-inf, inf] is not finite
